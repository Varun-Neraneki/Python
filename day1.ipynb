# %%
n=5
for i in range(n+1):
    for j in range(i):
        print('*',end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5 
for i in range(1,n+1):
    print('  ' * (n-i) +'* '*i)
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
n=5
for i in range(1,n + 1):
    print((n-i)*" ",end="  ")
    print(i * " *")
# Out:
#        *
#       * *
#      * * *
#     * * * *
#    * * * * *

# %%
n = 5
for i in range(n, 0, -1):
    for j in range(i):
        print('*', end=' ')
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 5
for i in range(n, 0, -1):
    print((n-i)*" ",end=" ")
    print(i * "*")
# Out:
#  *****
#   ****
#    ***
#     **
#      *

# %%
n=int(input("Enter the number:"))
for i in range(n):
    for j in range(n):
        print('*',end=' ')

    print()
# Out:
# Enter the number: 5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
n=int(input("Enter the number:"))
for i in range(n):
    print('* '*n)
# Out:
# Enter the number: 5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *
