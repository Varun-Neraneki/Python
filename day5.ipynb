# %%
for i in range(1,5):
    for j in range(1,5):
        if j==3:
            break
        print(i,j)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2
# 4 1
# 4 2

# %%
for i in range(5):
    if i<3:
        break
    print(i)

# %%
for i in range(5):
    if i>3:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(1,6):
    if i%2==0:
        continue
    if i==5:
        break
    print(i)
# Out:
# 1
# 3

# %%
Tuple 
methods

# %%
t=(1,2,3,4,5,6,7,8,9)
i=int(input("Enter the index"))
new_tuple = t[:i] + t[i+ 1:]
print(new_tuple)
# Out:
# Enter the index 3
# (1, 2, 3, 5, 6, 7, 8, 9)

# %%
# Program to find the repeated items in a tupl
t = (1, 2, 3, 2, 4, 5, 3, 6, 1)
count_dict = {}
for item in t:
    count_dict[item] = count_dict.get(item, 0) + 1
repeated_item = [item for item, count in count_dict.items() if count > 1]

print("Repeated items:", repeated_item)
# Out:
# Repeated items: [1, 2, 3]

# %%
Sets:
a.add()
a.update()
a.copy()
a.clear()
a.remove(12)
a.uninon() 
a.intersection(b) or print(a&b)
a.intersection_update(b)
a.difference(b)  print un-common elements from a and b
a.difference_difference(b) 
a.isdisjoints(b)  ture if two stes have a null intersetion
a.issuprset(b) 
a.issubset(b)
built-in fucnctions:
sum(): returns sum of all elements in the set
max():returns the largest item in the set
min():returns the smallest item in the set
len(): returns the length in the set
all(): returns true if all values are true

set comparision: returns a set based on exixting iterables
syntax: {expression(variable)for variable in input_set[predicate][, ...]}

Frozen set

# %%
res={s for s in[1,2,3] if s%2 }
print(res)
# Out:
# {1, 3}

# %%
Dictionary
A dictionary is a collection which is unordered, changeable and indexed

update:
d[1]="Hello"

deletee:
del d[1] or del(d)

methods:
pop():
d.pop('a')
popitem()
keys() returns list if dictionary dict's keys

values():

fromkeys(): create a new dictionary with keys from seq and values set to value
setdefault(): set dict[key]=default if key is not already un dict 

nested dictionary
dictionary compe

# %%
student_marks = {
    'sita': 95,
    'aakash': 88,
    'anvesh': 56,
    'honey': 41,
    'mallesh': 15,
    'arjun': 54,
    'mani': 29
}

for name in student_marks:
    marks = student_marks[name]
    
    if marks >= 90:
        grade = 'A'
    elif marks >= 75:
        grade = 'B'
    elif marks >= 50:
        grade = 'C'
    elif marks >= 35:
        grade = 'D'
    else:
        grade = 'F'
    
    print(name, "grade", grade)
# Out:
# sita grade A
# aakash grade B
# anvesh grade C
# honey grade D
# mallesh grade F
# arjun grade C
# mani grade F
