# %%
#Eg
class bikes:
    def __init__(self,name,cc,m,cost):
        self.name=name
        self.cc=cc
        self.m=m
        self.cost=cost
    def performance (self):
        print("abt bikes:",self.name,self.cc,self.m,self.cost)
gt=bikes("GT",650,12,4)
duke=bikes("duke",390,30,2)
gt.performance()
duke.performance()
# Out:
# abt bikes: GT 650 12 4
# abt bikes: duke 390 30 2

# %%
class bikes:
    def perf(self):
        print("gt","650cc",15,4)
gt=bikes()
duke=bikes()
gt.perf()
duke.perf()
# Out:
# gt 650cc 15 4
# gt 650cc 15 4

# %%
Instances 
a

# %%
#encaplusation
class cars:
    wheels=4
    def __init__(self,mil,car):
        self.mil=mil
        self.car=car
    def get_mil(self):
        return c1.mil
    def set_mil(self):
        c1.mil=12
        return c1.mil
    @staticmethod
    def info():
        print("hi  hello")
    @classmethod
    def infor(cls):
        return cls.wheels
print(cars.infor())
c1=cars(10,"BMW")
c2=cars(15,"audi")
c1.wheels=9
print(c1.mil)
print(c1.wheels)
print(c2.wheels)
print(c1.get_mil())
print(c1.set_mil())
print(c1.mil)
# Out:
# 4
# 10
# 9
# 4
# 10
# 12
# 12

# %%
Polymorphism-one name, many type 
1.duck typing
2.operator overloding
3.method overloading

# %%
#Polymorphism (Duck Typing)
class pycharm:
    def execute(self):
        print("Compiling")
        print("Running")
class myeditor:
    def execute(self):
        print("debugging")
        print("printing error")
        print("compiling")
        print("running")
class laptop:
    def code(self,ide):
        ide.execute()
ide=pycharm()
lap1=laptop()
lap1.code(ide)
# Out:
# Compiling
# Running

# %%
#operator over-loadig using magic methods
#operation over loading
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other):
        m1=self.m1+self.m2
        m2=self.m2+other.m2
        s3=student(m1,m2)
        return s3
    def __gt__(self,other):
        r1=self.m1+self.m2
        r2=other.m1+other.m2    
        if r1>r2:
            return True 
        else:
            return False
s1=student(59,65)
s2=student(67,85)
s3=s1+s2
print(s3.m1)
print(s3.m2)
if s1>s2:
    print("s1 having more marksthen s2")
else:
    print("s2 having more marks then s1")
# Out:
# 124
# 150
# s2 having more marks then s1

# %%
# method overloading
class math:
    def add(self,a=0,b=0,c=0):
        return a+b+c
m=math()
print(m.add(1,2))
print(m.add(1,2,3))
print(m.add())
# Out:
# 3
# 6
# 0

# %%
# Single level inheritence (over riding)
class Animal:
    def sound(self):
        return "Animals make different sounds"
class Dog(Animal):
    def s(self):
        return "dog barks"
d=Dog()
print(d.sound())
print(d.s())
# Out:
# Animals make different sounds
# dog barks

# %%
# Multiple Inheritence 
class engine:
    def engine_info(self):
        return "this is an engine"
class wheels:
    def wheels_info(self):
        return "car has 4 wheels"
class car(engine,wheels):
    def car_info(self):
        return "this a car"
c=car()
print(c.engine_info())
print(c.wheels_info())
print(c.car_info())
# Out:
# this is an engine
# car has 4 wheels
# this a car

# %%
# Multi-level inheritence
class Animal:
    def species(self):
        return "this is an animal"
class Mammal(Animal):
    def category(self):
        return "this is mammal"
class Human(Mammal):
    def speak(self):
        return "humans can speak"
h=Human()
print(h.species())
print(h.category())
print(h.speak())
# Out:
# this is an animal
# this is mammal
# humans can speak

# %%
# Hierarchical Inheritence
class vehicle:
    def fuel_type(self):
        return "vehicle can use petrol, desile, anf LPG"
class car(vehicle):
    def type(self):
        return "car is a 4-wheeler"
class bike(vehicle):
    def type(self):
        return "bike is a 2-wheeler"
c=car()
b=bike()
print(c.fuel_type())
print(c.type())
print(b.type())
# Out:
# vehicle can use petrol, desile, anf LPG
# car is a 4-wheeler
# bike is a 2-wheeler

# %%
# Hybrid Inheritence

class Person:
    def info(self):
        print("I am a Person")
class Student(Person):
    def role(self):
        print("I am a Student")
class Sportsperson:
    def talent(self):
        print("I am good at Sports")
class StudentAthlete(Student, Sportsperson):
    def identity(self):
        print("I am a Student Athlete")
sa = StudentAthlete()
sa.info()       
sa.role()       
sa.talent()     
sa.identity()
# Out:
# I am a Person
# I am a Student
# I am good at Sports
# I am a Student Athlete

# %%
# Hybrid Inheritence
class A:
    def display(self):
        print("Display from class A")
class B(A):
    def display(self):
        print("Display from B class")
class C:
    def show(self):
        print("Hi from C class")
class D(B,C):
    def display(self):
        print("Display from D class")
d1=D()
d1.display()
d1.show()
print(D.mro())
# Out:
# Display from D class
# Hi from C class
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.A'>, <class '__main__.C'>, <class 'object'>]

# %%
# Abstraction
# from abstract_class import Vehicle
# class Bike(Vehicle):
#     def __init__(self,n,color):
#         super().__init__(n)
#         self.color=color
#     def start(self):
#         print("Start with kick")
# class Scooty(Vehicle):
#     def start(self):
#         print("Self start")
# class car(Vehicel):
#     def __init__(self,n,x):
#         super.__init__(n)
#         self.no_of_gears=6
#     def start(self):
#         print("Start with the key")
# from abstractio_example import *
# bike=Bike(2,"Black")
# bike.start()
# scooty=Scooty(2)
# scooty.start()

from abc import ABC,abstractmethod
class Vehicle(ABC):
    def __init__(self,n):
        self.no_of_tyres=n
    @abstractmethod
    def start(self):
        pass
    def manfac(self):
        pass
    def display(self):
        print("Hi i am calling from vehicle class")

# %%
Searching:
1. Linear search
2. binary search

# %%
# Linear Search 
arr=[7,5,1,3,8,9,2,6]
key=(int(input("Enter key:")))
for i in range(len(arr)):
    if (arr[i]==key):
        print("Key at index:",i)
        break
else:
    print("Not found")
# Out:
# Enter key: 34
# Not found

# %%
# Linear Search 

def search(list1,key):
    for i in range(len(list1)):
        if key==list1[i]:
            print("Key found at index:",i)
            break
    else:
        print("Key not found")
list1=[7,5,1,3,8,9,2,6]
key=(int(input("Enter key:"))) 
search(list1,key)
# Out:
# Enter key: 3
# Key found at index: 3

# %%
# Binary search
arr=[7,5,1,3,8,9,2,6]
arr.sort()   
print(arr)
key=int(input("Enter key:"))
low,high=0,len(arr)-1

def search(arr,key,low,high):
    while low <= high:
        mid = (low + high) // 2
        if key == arr[mid]:
            print("Key found at index:", mid)
            return
        elif key > arr[mid]:
            low = mid + 1
        else:
            high = mid - 1
    print("Key not found")

search(arr,key,low,high)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9]
# Enter key: 89
# Key not found

# %%
# Binary Search
arr = [7, 5, 1, 3, 8, 9, 2, 6]
arr.sort()  
print("Sorted array:", arr)

key = int(input("Enter key: "))

def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2  
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1
    return -1

result = binary_search(arr, key)

if result != -1:
    print("Key found at index:", result)
else:
    print("Key not found")
# Out:
# Sorted array: [1, 2, 3, 5, 6, 7, 8, 9]
# Enter key:  5
# Key found at index: 3

# %%
# First occurrence of element using binary search
def first_occurrence(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            print("First occurrence of", key, "is at index:", i)
            return
    print("Key not found")
arr = [5, 2, 3, 7, 2, 4, 2,5]
key = int(input("Enter key: "))
first_occurrence(arr, key)
# Out:
# Enter key:  3
# First occurrence of 3 is at index: 2

# %%
#last occurence
def last_occurrence_unsorted(arr, key):
    for i in range(len(arr) - 1, -1, -1): 
        if arr[i] == key:
            print("Last occurrence of", key, "is at index:", i)
            return
    print("Key not found")


arr = [5, 2, 3, 7, 2, 4, 2]
key = int(input("Enter key: "))
last_occurrence_unsorted(arr, key)
# Out:
# Enter key:  2
# Last occurrence of 2 is at index: 6

# %%
#First Occurance
def binary_search_first_occurrence(arr, target):
    low = 0
    high = len(arr) - 1
    result = -1

    while low <= high:
        mid = (low + high) // 2

        if target == arr[mid]:
            result = mid     
            high = mid - 1     
        elif target < arr[mid]:
            high = mid - 1
        else:
            low = mid + 1

    return result


list1 = [1, 2, 2, 4, 4, 5]
target = 4
print("First occurrence at index:", binary_search_first_occurrence(list1, target))
# Out:
# First occurrence at index: 3

# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    result = -1

    while low <= high:
        mid = (low + high) // 2

        if target == arr[mid]:
            result = mid     
            low = mid + 1    
        elif target < arr[mid]:
            high = mid - 1
        else:
            low = mid + 1

    return result


list1 = [1, 2, 2, 4, 4, 5]
target = 4
print("Last occurrence at index:", binary_search(list1, target))
# Out:
# Last occurrence at index: 4

# %%
# Find the minimum element from rotated sorted array
def find_min_rotated(arr):
    low, high = 0, len(arr) - 1

    while low < high:
        mid = (low + high) // 2
        if arr[mid] > arr[high]:
            low = mid + 1
        else:
            high = mid
    return arr[low]   
arr = [4, 5, 6, 7, 10, 1, 2]
print("Minimum element:", find_min_rotated(arr))
# Out:
# Minimum element: 1

# %%
# Find the minimum element from rotated sorted array
nums=[4,5,6,7,1,2]
low,high=0,len(nums-1)

# %%
def find_peak(arr):
    low, high = 0, len(arr) - 1

    while low <= high:
        mid = (low + high) // 2
        left = arr[mid - 1] if mid > 0 else float('-inf')
        right = arr[mid + 1] if mid < len(arr) - 1 else float('-inf')

        if arr[mid] >= left and arr[mid] >= right:
            return arr[mid]  # return the peak element
        elif arr[mid] < right:
            low = mid + 1
        else:
            high = mid - 1

arr = [1, 2, 3, 4, 1, 5]
print("Peak element:", find_peak(arr))
# Out:
# Peak element: 5

# %%
nums=[1,2,3,1]
low,high=0,len(nums)-1
while low<high:
    mid=(low+high)//2
    if mid *mid<=n:
        result=mid
        low=mid+1
    else:
        high=mid
print(low)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 while low<high:
#       4     mid=(low+high)//2
# ----> 5     if mid *mid<=n:
#       6         result=mid
#       7         low=mid+1
#
# NameError: name 'n' is not defined
